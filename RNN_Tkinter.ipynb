# %%
pip install pandas numpy scikit-learn langdetect googletrans==4.0.0rc1 joblib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 13.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 54.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 3.9 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17396 sha256=e49ea7d7ac4f6a6ea3d9c31e69d304b25acfd7a7709efd43d73f913db41d5fcf
# ...

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

import joblib

from langdetect import detect

from googletrans import Translator

import tkinter as tk
from tkinter import messagebox

# %%
data = pd.read_csv("/content/Language Detection.csv (1).zip")

print(data.head())

print(data.columns)
# Out:
#                                                 Text Language
# 0   Nature, in the broadest sense, is the natural...  English
# 1  "Nature" can refer to the phenomena of the phy...  English
# 2  The study of nature is a large, if not the onl...  English
# 3  Although humans are part of nature, human acti...  English
# 4  [1] The word nature is borrowed from the Old F...  English
# Index(['Text', 'Language'], dtype='object')

# %%
X = data["Text"]

y = data["Language"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
model = Pipeline([
    ("tfidf", TfidfVectorizer()),
    ("classifier", LogisticRegression())
])

model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('classifier', LogisticRegression())])

# %%
prediction = model.predict(X_test)

accuracy = accuracy_score(y_test, prediction)

print("Accuracy :", accuracy * 100)
# Out:
# Accuracy : 96.37330754352031

# %%
joblib.dump(model, "language_model.pkl")
# Out:
# ['language_model.pkl']

# %%
model = joblib.load("language_model.pkl")

# %%
translator = Translator()

# %%
def detect_language():

    text = text_box.get("1.0", tk.END).strip()

    if text == "":
        messagebox.showwarning("Warning", "Please enter text")
        return

    language = model.predict([text])[0]

    translation = translator.translate(text, dest="en")

    language_result.config(text="Detected Language : " + language)

    translation_result.config(text="English Translation : " + translation.text)

# %%
def clear():

    text_box.delete("1.0", tk.END)

    language_result.config(text="Detected Language :")

    translation_result.config(text="English Translation :")

# %%
# login tkinter

import tkinter as tk
from tkinter import *
from tkinter import messagebox

a = tk.Tk()
a.geometry("1400x900")
a.config(bg="#E6E6FA")
a.title("/content/Language Detection.csv (1).zip")

# Title
title = Label(a, text="LOGIN", font=("Palatino Linotype", 40), bg="#E6E6FA", fg="black")
title.pack()

# Username
usernameLabel = Label(a, text="Name", font=("Palatino Linotype", 15), bg="#E6E6FA", fg="black")
usernameLabel.place(x=550, y=200)

usernameEntry = Entry(a, font=("Palatino Linotype", 20), bg="white", fg="black")
usernameEntry.place(x=550, y=250)

# Email
emailLabel = Label(a, text="Mail", font=("Palatino Linotype", 15), bg="#E6E6FA", fg="black")
emailLabel.place(x=550, y=300)

emailEntry = Entry(a, font=("Palatino Linotype", 20), bg="white", fg="black")
emailEntry.place(x=550, y=350)

# Phone
phoneLabel = Label(a, text="Mobile", font=("Palatino Linotype", 15), bg="#E6E6FA", fg="black")
phoneLabel.place(x=550, y=400)

phoneEntry = Entry(a, font=("Palatino Linotype", 20), bg="white", fg="black")
phoneEntry.place(x=550, y=450)

# Submit function
def submit():
    username = usernameEntry.get()
    email = emailEntry.get()
    phone = phoneEntry.get()

    if username == "" or email == "" or phone == "":
        messagebox.showwarning("LOGIN", "Login Terminated: Fill all the details")
    else:
        if email.endswith("@gmail.com") and phone.isdigit() and len(phone) == 10:
            messagebox.showinfo("LOGIN", "Login Successful")
            a.destroy()
            import language
        else:
            messagebox.showerror("LOGIN", "Login Terminated: Enter valid data")

# Submit Button
submitButton = Button(a, text="Submit", command=submit,
                      font=("Palatino Linotype", 20),
                      bg="Firebrick", fg="white")

submitButton.place(x=570, y=520)

a.mainloop()





          #Language

import tkinter as tk
from tkinter import *
from tkinter import messagebox

a = tk.Tk()
a.geometry("1400x900")
a.config(bg="#E6E6FA")
a.title("/content/Language Detection.csv (1).zip")

from tkinter import *

# Create Window
a = Tk()

a.title("Language Detection and Translation System")
a.geometry("1400x800")
a.configure(bg="#E6E6FA")

# ---------------- Title ---------------- #

l1 = Label(
    a,
    text="Language Detection and Translation System",
    font=("Palatino Linotype", 32, "bold"),
    bg="#E6E6FA",
    fg="darkblue"
)

l1.pack(pady=20)

# ---------------- Subtitle ---------------- #

l2 = Label(
    a,
    text="Select a Language",
    font=("Palatino Linotype", 22),
    bg="#E6E6FA",
    fg="black"
)

l2.pack(pady=20)

# ---------------- Function ---------------- #

def language_selected(language):
    print("Selected Language:", language)

# ---------------- Buttons ---------------- #

Button(
    a,
    text="Italian",
    font=("Palatino Linotype",18),
    bg="FireBrick",
    fg="white",
    width=25,
    command=lambda: language_selected("Italian")
).pack(pady=10)

Button(
    a,
    text="French",
    font=("Palatino Linotype",18),
    bg="FireBrick",
    fg="white",
    width=25,
    command=lambda: language_selected("French")
).pack(pady=10)

Button(
    a,
    text="Tamil",
    font=("Palatino Linotype",18),
    bg="FireBrick",
    fg="white",
    width=25,
    command=lambda: language_selected("Tamil")
).pack(pady=10)

Button(
    a,
    text="Portuguese",
    font=("Palatino Linotype",18),
    bg="FireBrick",
    fg="white",
    width=25,
    command=lambda: language_selected("Portuguese")
).pack(pady=10)

Button(
    a,
    text="Malayalam",
    font=("Palatino Linotype",18),
    bg="FireBrick",
    fg="white",
    width=25,
    command=lambda: language_selected("Malayalam")
).pack(pady=10)

# Exit Button

Button(
    a,
    text="Exit",
    font=("Palatino Linotype",18),
    bg="red",
    fg="white",
    width=25,
    command=a.destroy
).pack(pady=20)

a.mainloop()






      #langugae detail

import tkinter as tk

root = tk.Tk()
root.title("Language Detection System")
root.geometry("500x400")

title = tk.Label(root, text="Language Detection and Translation System",
                 font=("Arial", 16, "bold"))
title.pack(pady=10)

tk.Label(root, text="Enter Text:").pack()

text_box = tk.Text(root, height=5, width=40)
text_box.pack()

detect_btn = tk.Button(root, text="Detect Language")
detect_btn.pack(pady=5)

language_label = tk.Label(root, text="Detected Language:")
language_label.pack()

translation_label = tk.Label(root, text="English Translation:")
translation_label.pack()

root.mainloop()




from tkinter import *
from PIL import Image, ImageTk

a = Tk()
a.title("Language Detection System")
a.geometry("1400x700")
a.configure(bg="#E6E6FA")

# ---------------- Title ---------------- #

title = Label(
    a,
    text="Language Detection and Translation System",
    font=("Palatino Linotype", 28, "bold"),
    bg="#E6E6FA",
    fg="darkblue"
)
title.pack(pady=20)

# ---------------- Function ---------------- #

def select_language(language):
    print("Selected Language:", language)

# ---------------- Italian ---------------- #

img1 = Image.open("italian.jpg")
img1 = ImageTk.PhotoImage(img1.resize((200,250)))

Label(a, image=img1).place(x=80, y=120)

Button(
    a,
    text="Italian",
    font=("Palatino Linotype",15),
    bg="FireBrick",
    fg="white",
    width=18,
    command=lambda: select_language("Italian")
).place(x=80, y=390)

# ---------------- French ---------------- #

img2 = Image.open("french.jpg")
img2 = ImageTk.PhotoImage(img2.resize((200,250)))

Label(a, image=img2).place(x=360, y=120)

Button(
    a,
    text="French",
    font=("Palatino Linotype",15),
    bg="FireBrick",
    fg="white",
    width=18,
    command=lambda: select_language("French")
).place(x=360, y=390)

# ---------------- Tamil ---------------- #

img3 = Image.open("tamil.jpg")
img3 = ImageTk.PhotoImage(img3.resize((200,250)))

Label(a, image=img3).place(x=640, y=120)

Button(
    a,
    text="Tamil",
    font=("Palatino Linotype",15),
    bg="FireBrick",
    fg="white",
    width=18,
    command=lambda: select_language("Tamil")
).place(x=640, y=390)

# ---------------- Malayalam ---------------- #

img4 = Image.open("malayalam.jpg")
img4 = ImageTk.PhotoImage(img4.resize((200,250)))

Label(a, image=img4).place(x=920, y=120)

Button(
    a,
    text="Malayalam",
    font=("Palatino Linotype",15),
    bg="FireBrick",
    fg="white",
    width=18,
    command=lambda: select_language("Malayalam")
).place(x=920, y=390)

a.mainloop()

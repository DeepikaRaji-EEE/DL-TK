# %%
pip install pandas numpy tensorflow scikit-learn

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input,
    Embedding,
    MultiHeadAttention,
    LayerNormalization,
    Dense,
    GlobalAveragePooling1D
)
from tensorflow.keras.utils import to_categorical

# %%
import pandas as pd
import csv

df = pd.read_csv(
    "/content/news.csv",
    engine='python',
    quoting=csv.QUOTE_NONE,
    on_bad_lines='skip'
)

print(df.head())
# Out:
#    id                                              title  \
# 0   2  Fed's Charles Plosser sees high bar for change...
# 1   3  US open: Stocks fall after Fed official hints ...
# 2   5  Fed's Plosser: Nasty Weather Has Curbed Job Gr...
# 3   6  Plosser: Fed May Have to Accelerate Tapering Pace
# 4   7          Fed's Plosser: Taper pace may be too slow
#
#                                                  url     publisher category  \
# 0  http://www.livemint.com/Politics/H2EvwJSK2VE6O...      Livemint        b
# 1  http://www.ifamagazine.com/news/us-open-stocks...  IFA Magazine        b
# 2  http://www.moneynews.com/Economy/federal-reser...     Moneynews        b
# 3  http://www.nasdaq.com/article/plosser-fed-may-...        NASDAQ        b
# 4  http://www.marketwatch.com/story/feds-plosser-...   MarketWatch        b
#
#                            story             hostname      timestamp
# 0  ddUyU0VZz0BRneMioxUPQVP6sIxvM     www.livemint.com  1394470371207
# ...

# %%
# Load the first 1000 news headlines/articles
texts = df["url"].astype(str).head(1000)

# %%
# Split the data into input features (X) and target labels (y)

# %%
# Tokenize the news text

# %%
seed = input("Enter the beginning of a news headline: ")
# Out:
# Enter the beginning of a news headline: news

# %%
pip install transformers torch

# %%
from transformers import pipeline

# Load a pre-trained LLM
chatbot = pipeline(
    "text-generation",
    model="gpt2"
)

prompt = input("Enter a prompt:")

result = chatbot(
    prompt,
    max_length=30,
    num_return_sequences=1
)

print(result[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Enter a prompt:AI is a
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# AI is a company that has been around for decades and has always been committed to the goal of making it easier for people to access its services."
#
# The company says the technology allows it to "provide new value for the public while also providing services that are more affordable for an increasing number of people."
#
# "We offer a wide range of services (which include:
#
# ...
